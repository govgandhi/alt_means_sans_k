# %%
import sys
# !{sys.executable} -m pip install fast_hdbscan
# Out:
# Collecting fast_hdbscan
#   Downloading fast_hdbscan-0.1.3.tar.gz (15 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.21 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from fast_hdbscan) (1.24.3)
# Requirement already satisfied: numba>=0.56 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from fast_hdbscan) (0.57.1)
# Requirement already satisfied: scikit-learn>=1.1 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from fast_hdbscan) (1.3.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from numba>=0.56->fast_hdbscan) (0.40.1)
# Requirement already satisfied: scipy>=1.5.0 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from scikit-learn>=1.1->fast_hdbscan) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from scikit-learn>=1.1->fast_hdbscan) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /nfs/nfs9/home/nobackup/gogandhi/miniconda3/envs/kmeans_env/lib/python3.9/site-packages (from scikit-learn>=1.1->fast_hdbscan) (2.2.0)
# Building wheels for collected packages: fast_hdbscan
#   Building wheel for fast_hdbscan (pyproject.toml) ... done
#   Created wheel for fast_hdbscan: filename=fast_hdbscan-0.1.3-py3-none-any.whl size=15269 sha256=82cbbc82426df878a0ce25bf5dcf57d0444544876b2db55891aa0cdb5eeb8462
#   Stored in directory: /nfs/nfs2/home/gogandhi/.cache/pip/wheels/bb/e6/e0/ae91ad36a8d1496382103a64c3086c8e2fb02a3bf7406f933d
# Successfully built fast_hdbscan
# Installing collected packages: fast_hdbscan
# Successfully installed fast_hdbscan-0.1.3

# %%
import fast_hdbscan
from sklearn.datasets import make_blobs

data, _ = make_blobs(1000)

clusterer = fast_hdbscan.HDBSCAN(min_cluster_size=10)
cluster_labels = clusterer.fit_predict(data)

import matplotlib.pyplot as plt

# Visualize the clusters
plt.scatter(data[:, 0], data[:, 1], c=cluster_labels, cmap='viridis', s=10)
plt.title('HDBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
# But does it work well with our data, or does it still need parameter tuning?
# Continue in X Means et alia.ipynb (Update: It works fast enough for low dimensions)

# %%
data
# Out:
# array([[ 0.57195074,  5.31934102],
#        [-3.23099859, -2.17698169],
#        [ 6.39705397, -0.69181634],
#        ...,
#        [-3.51737534, -2.30544572],
#        [ 1.3722763 ,  6.66739408],
#        [-4.80480291, -0.15040865]])
