# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle

path_name = {}
path_name["5,3"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_5_3.0_1"
path_name["10,3"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_10_3.0_1"
path_name["50,3"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_50_3.0"
path_name["5,2"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_5_2.0"
path_name["10,2"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_10_2.0"
path_name["50,2"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_50_2"
path_name["50,2.5"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_50_2.5"


path_name["emb"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_emb_change_10000_50_3.0_immutable"
path_name["dim"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_dim_change_10000_50_3.0"
path_name["walklen"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_walklen_change_10000_50_3.0"
path_name["winlen"] = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_winlen_change_10000_50_3.0"

csv_file_path = path_name["50,3"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])
plt.figure(figsize=(7,4))

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    plt.plot(mean_values.index, mean_values, '-o',label=column)
    plt.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

plt.xlabel(r'Mixing Parameter: $\mu$')
plt.ylabel('Element Centric Similarity')
plt.legend(title="Algorithm", loc='upper right', bbox_to_anchor=(1.3, 0.8))
plt.grid(True)
plt.tight_layout()

plt.title(rf'Runs: {10} | Nodes: {1000} | $\tau$: {3.0} | $<k>$: {50}')


# Save the figure

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Load the image
image_path = "/nobackup/gogandhi/alt_means_sans_k/Figs/Abstract/Figure_Part1.jpeg"
image_path = "/nobackup/gogandhi/alt_means_sans_k/Figs/Abstract/workflow_figure.png"
img = plt.imread(image_path)

# Create a 3x4 grid with the first column for the image and the remaining for subplots
fig = plt.figure(figsize=(18, 9))
gs = gridspec.GridSpec(3, 4, width_ratios=[1.4, 1, 1, 1])

# Add figure label
fsize = 35
fonts=20
fig.text(0.04, 0.95, "a)", fontsize=fsize)

# Add image to the first column
ax_img = plt.subplot(gs[:, 0])
ax_img.imshow(img,aspect='equal')
ax_img.axis('off')  # Hide axes for the image

# Create a 3x3 grid for subplots
axs = [[plt.subplot(gs[i, j + 1]) for j in range(3)] for i in range(3)]

# Customize each subplot as needed
for i in range(3):
    # Add row label
    axs[i][0].text(-0.35, 1.05, f"{chr(ord('b') + i)})", transform=axs[i][0].transAxes, fontsize=fsize)
    
    for j in range(3):
        axs[i][j].set_title(f'Section {i * 3 + j + 1}')  # Set subplot title
        #axs[i][j].plot(range(10), label=f'Plot {i * 3 + j + 1}')  # Example plot for each subplot
        #axs[i][j].legend()  # Display legend
#fig.tight_layout()

######Section 1

ax = axs[0][0]

csv_file_path = path_name["5,3"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
ax.set_ylabel('E-Sim', fontsize = fonts)
ax.legend(title="Algorithm", loc='upper right')#, bbox_to_anchor=(1.3, 0.8))
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {5}', fontsize = fonts)



#####Section 2

ax = axs[0][1]

csv_file_path = path_name["10,3"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
#ax.set_ylabel('E-Sim', fontsize = fonts)
#ax.legend(title="Algorithm", loc='upper right', bbox_to_anchor=(1.3, 0.8))
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {10}', fontsize = fonts)

#####Section 3

ax = axs[0][2]

csv_file_path = path_name["50,3"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
#ax.set_ylabel('E-Sim', fontsize = fonts)
#ax.legend(title="Algorithm", loc='upper right', bbox_to_anchor=(1.3, 0.8))
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {50}', fontsize = fonts)

#####Section 4

ax = axs[1][0]

csv_file_path = path_name["50,2"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
ax.set_ylabel('E-Sim', fontsize = fonts)
#ax.legend(title="Algorithm", loc='upper right', bbox_to_anchor=(1.3, 0.8))
ax.grid(False)
ax.set_title(rf'$\tau$: {2.0}, $\langle k \rangle$: {50}', fontsize = fonts)

#####Section 5

ax = axs[1][1]

csv_file_path = path_name["50,2.5"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
#ax.set_ylabel('E-Sim', fontsize = fonts)
#ax.legend(title="Algorithm", loc='upper right', bbox_to_anchor=(1.3, 0.8))
ax.grid(False)
ax.set_title(rf'$\tau$: {2.5}, $\langle k \rangle$: {50}', fontsize = fonts)


#####Section 6

ax = axs[1][2]

csv_file_path = path_name["50,3"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
#ax.set_ylabel('E-Sim', fontsize = fonts)
#ax.legend(title="Algorithm", loc='upper right', bbox_to_anchor=(1.3, 0.8))
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {50}', fontsize = fonts)

# #####Section 7
ax = axs[2][0]

csv_file_path = path_name["dim"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
runs = result_df['run_no'].unique()
df_grouped = result_df.groupby(['mu', 'dim']).agg(['mean', 'std'])

score_key = 'proposed'

for dim in df_grouped.index.levels[1]:
    index = [i for i, j in list(df_grouped.loc(axis=0)[:, dim][score_key]['mean'].index)]
    mean_values = df_grouped.loc(axis=0)[:, dim][score_key]['mean']
    std_values = df_grouped.loc(axis=0)[:, dim][score_key]['std']

    ax.plot(index, mean_values, '-o', label=f'{dim}')
    ax.fill_between(index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
ax.set_ylabel('E-Sim', fontsize = fonts)
ax.legend(title="Dimension", loc='best')#, bbox_to_anchor=(1.3, 0.8))

ax.grid(False)
ax.set_title(rf'Embedding Vector Dimension', fontsize = fonts)

# #####Section 8
ax = axs[2][1]

csv_file_path = path_name["walklen"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
runs = result_df['run_no'].unique()
df_grouped = result_df.groupby(['mu', 'walklen']).agg(['mean', 'std'])

score_key = 'proposed'

for walk_length in df_grouped.index.levels[1]:
    index = [i for i, j in list(df_grouped.loc(axis=0)[:, walk_length][score_key]['mean'].index)]
    mean_values = df_grouped.loc(axis=0)[:, walk_length][score_key]['mean']
    std_values = df_grouped.loc(axis=0)[:, walk_length][score_key]['std']

    ax.plot(index, mean_values, '-o', label=f'{walk_length}')
    ax.fill_between(index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
#ax.set_ylabel('E-Sim', fontsize = fonts)
ax.legend(title="Walk length", loc='best')#, bbox_to_anchor=(1.3, 0.8))

ax.grid(False)
ax.set_title(rf'Random Walk Length', fontsize = fonts)


# #####Section 9
ax = axs[2][2]

csv_file_path = path_name["winlen"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
runs = result_df['run_no'].unique()
df_grouped = result_df.groupby(['mu', 'window_length']).agg(['mean', 'std'])

score_key = 'proposed'

for window_length in df_grouped.index.levels[1]:
    index = [i for i, j in list(df_grouped.loc(axis=0)[:, window_length][score_key]['mean'].index)]
    mean_values = df_grouped.loc(axis=0)[:, window_length][score_key]['mean']
    std_values = df_grouped.loc(axis=0)[:, window_length][score_key]['std']

    ax.plot(index, mean_values, '-o', label=f'{window_length}')
    ax.fill_between(index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
#ax.set_ylabel('E-Sim', fontsize = fonts)
ax.legend(title="Window length", loc='best')#, bbox_to_anchor=(1.3, 0.8))

ax.grid(False)
ax.set_title(rf'Window Length', fontsize = fonts)

#fig.suptitle()
# Adjust layout for better appearance
#plt.tight_layout()
for i in [0,1]:
    for j in [0,1,2]:
        axs[i][j].sharex(axs[0][0])
        axs[i][j].sharey(axs[0][0])
fig.tight_layout()
#plt.savefig("/nobackup/gogandhi/alt_means_sans_k/Figs/Abstract/figure_abstract_scaled_results.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd

# Load the image
image_path = "/nobackup/gogandhi/alt_means_sans_k/Figs/Abstract/workflow_figure.png"
img = plt.imread(image_path)

# Create a 3x4 grid with the first column for the image and the remaining for subplots
fig = plt.figure(figsize=(18, 9))
gs = gridspec.GridSpec(3, 4, width_ratios=[1.4, 1, 1, 1], wspace=0.15, hspace=0.35)

# Add figure label
fsize = 35
fonts = 20

# Add image to the first column
ax_img = plt.subplot(gs[:, 0])
ax_img.imshow(img, aspect='equal')
ax_img.axis('off')  # Hide axes for the image

# Create a 3x3 grid for subplots
fig.patch.set_facecolor('#0d375e')

# Transpose the grid positions
axs = [[plt.subplot(gs[j, i + 1]) for j in range(3)] for i in range(3)]

for row in axs:
    for ax in row:
        ax.set_facecolor("#FFFDEA")
        ax.title.set_color('white')
        ax.xaxis.label.set_color('white')
        ax.yaxis.label.set_color('white')
        ax.tick_params(axis='x', colors='white')
        ax.tick_params(axis='y', colors='white')

for i in range(3):
    for j in range(3):
        if i == 0 and j == 0:
            continue  # Skip the first subplot
        axs[i][j].sharex(axs[0][0])
        axs[i][j].sharey(axs[0][0])


# Customize each subplot as needed
for i in range(3):
    for j in range(3):
        axs[j][i].set_title(f'Section {i * 3 + j + 1}')  # Set subplot title

###### Section 1
ax = axs[0][0]
csv_file_path = path_name["5,3"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_ylabel('E-Sim', fontsize=fonts)
ax.legend(title="Algorithm", loc='upper right')
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {5}', fontsize=fonts)

##### Section 2
ax = axs[0][1]
csv_file_path = path_name["10,3"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_ylabel('E-Sim', fontsize=fonts)
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {10}', fontsize=fonts)

##### Section 3
ax = axs[0][2]
csv_file_path = path_name["50,3"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize=fonts)
ax.set_ylabel('E-Sim', fontsize=fonts)
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {50}', fontsize=fonts)

##### Section 4
ax = axs[1][0]
csv_file_path = path_name["50,2"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.grid(False)
ax.set_title(rf'$\tau$: {2.0}, $\langle k \rangle$: {50}', fontsize=fonts)

##### Section 5
ax = axs[1][1]
csv_file_path = path_name["50,2.5"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

#ax.set_xlabel(r'$\mu$', fontsize=fonts)
ax.grid(False)
ax.set_title(rf'$\tau$: {2.5}, $\langle k \rangle$: {50}', fontsize=fonts)

##### Section 6
ax = axs[1][2]
csv_file_path = path_name["50,3"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
df_grouped = result_df.groupby('mu').agg(['mean', 'std'])

for column in df_grouped.columns.levels[0][1:]:
    mean_values = df_grouped[column]['mean']
    std_values = df_grouped[column]['std']
    ax.plot(mean_values.index, mean_values, '-o', label=column)
    ax.fill_between(mean_values.index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize=fonts)
ax.grid(False)
ax.set_title(rf'$\tau$: {3.0}, $\langle k \rangle$: {50}', fontsize=fonts)

##### Section 7
ax = axs[2][0]
csv_file_path = path_name["dim"] + "/result_stream.csv"
result_df = pd.read_csv(csv_file_path)
runs = result_df['run_no'].unique()
df_grouped = result_df.groupby(['mu', 'dim']).agg(['mean', 'std'])

score_key = 'proposed'

for dim in df_grouped.index.levels[1]:
    index = [i for i, j in list(df_grouped.loc(axis=0)[:, dim][score_key]['mean'].index)]
    mean_values = df_grouped.loc(axis=0)[:, dim][score_key]['mean']
    std_values = df_grouped.loc(axis=0)[:, dim][score_key]['std']
    ax.plot(index, mean_values, '-o', label=f'{dim}')
    ax.fill_between(index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.legend(title="Dimension", loc='best')
ax.grid(False)
ax.set_title(rf'Embedding Dimension', fontsize=fonts)

##### Section 8
ax = axs[2][1]

csv_file_path = path_name["walklen"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
runs = result_df['run_no'].unique()
df_grouped = result_df.groupby(['mu', 'walklen']).agg(['mean', 'std'])

score_key = 'proposed'

for walk_length in df_grouped.index.levels[1]:
    index = [i for i, j in list(df_grouped.loc(axis=0)[:, walk_length][score_key]['mean'].index)]
    mean_values = df_grouped.loc(axis=0)[:, walk_length][score_key]['mean']
    std_values = df_grouped.loc(axis=0)[:, walk_length][score_key]['std']
    ax.plot(index, mean_values, '-o', label=f'{walk_length}')
    ax.fill_between(index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.legend(title="Walk length", loc='best')
ax.grid(False)
ax.set_title(rf'Random Walk Length', fontsize = fonts)

##### Section 9
ax = axs[2][2]

csv_file_path = path_name["winlen"] + "/result_stream.csv"

result_df = pd.read_csv(csv_file_path)
runs = result_df['run_no'].unique()
df_grouped = result_df.groupby(['mu', 'window_length']).agg(['mean', 'std'])

score_key = 'proposed'

for window_length in df_grouped.index.levels[1]:
    index = [i for i, j in list(df_grouped.loc(axis=0)[:, window_length][score_key]['mean'].index)]
    mean_values = df_grouped.loc(axis=0)[:, window_length][score_key]['mean']
    std_values = df_grouped.loc(axis=0)[:, window_length][score_key]['std']
    ax.plot(index, mean_values, '-o', label=f'{window_length}')
    ax.fill_between(index, mean_values - std_values, mean_values + std_values, alpha=0.2)

ax.set_xlabel(r'$\mu$', fontsize = fonts)
ax.legend(title="Window length", loc='best')
ax.grid(False)
ax.set_title(rf'Window Length', fontsize = fonts)

for i in [0, 1]:
    for j in [0, 1, 2]:
        axs[i][j].sharex(axs[0][0])
        axs[i][j].sharey(axs[0][0])

fig.tight_layout()
plt.savefig("/nobackup/gogandhi/alt_means_sans_k/Figs/Abstract/figure_abstract_tranposed_plot.svg",format='svg', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_37293/442155601.py:217: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
