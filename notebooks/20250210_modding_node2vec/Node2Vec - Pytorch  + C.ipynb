# %%
import torch
from torch.utils.cpp_extension import load

# This will compile and load the C++ extension.
skipgram_ops = load(name="skipgram_ops", sources=["skipgram_ops.cpp"], verbose=True)
# Out:
# Using /nfs/nfs2/home/gogandhi/.cache/torch_extensions/py39_cu124 as PyTorch extensions root...
# No modifications detected for re-loaded extension module skipgram_ops_v2, skipping build step...
# Loading extension module skipgram_ops_v2...

# %%
import time
import random
import numpy as np
import networkx as nx

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import lfr
import sys
import cProfile, pstats

# %%
##############################################
# Block 1: Setup and Random Walk Generation  #
##############################################

def generate_random_walks(G, num_walks=10, walk_length=10):
    """
    Generate random walks over the graph G.
    Note: For larger graphs, consider using more efficient vectorized implementations or libraries like 
    StellarGraph which implement efficient random walk sampling.
    """
    walks = []
    nodes = list(G.nodes())
    for _ in range(num_walks):
        random.shuffle(nodes)
        for node in nodes:
            walk = [node]
            for i in range(walk_length - 1):
                cur = walk[-1]
                neighbors = list(G.neighbors(cur))
                if len(neighbors) == 0:
                    break
                walk.append(random.choice(neighbors))
            walks.append(walk)
    return walks

##############################################
# Block 2: Generating SkipGram Pairs         #
##############################################

def generate_skipgram_pairs(walks, window_size=2):
    """
    For each walk, generate (center, context) pairs using a sliding window.
    Consider profiling this block using line_profiler if walks or window_size are large.
    """
    pairs = []
    for walk in walks:
        L = len(walk)
        for i, center in enumerate(walk):
            start = max(0, i - window_size)
            end = min(L, i + window_size + 1)
            for j in range(start, end):
                if i == j:
                    continue
                pairs.append((center, walk[j]))
    return pairs

##############################################
# Block 3: Dataset and DataLoader            #
##############################################

class SkipGramDataset(Dataset):
    def __init__(self, pairs):
        self.pairs = pairs

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        center, context = self.pairs[idx]
        return center, context

# %%
class SkipGramModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, sim_type="dot"):
        """
        Parameters:
          vocab_size: int – number of nodes.
          embedding_dim: int – embedding dimensionality.
          sim_type: str – similarity measure; options: "dot", "euclidean", "cosine".
        """
        super(SkipGramModel, self).__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        
        # Map similarity measure to an integer for the C++ extension.
        sim_type_lower = sim_type.lower()
        if sim_type_lower == "dot":
            self.sim_type = 0
        elif sim_type_lower == "euclidean":
            self.sim_type = 1
        elif sim_type_lower == "cosine":
            self.sim_type = 2
        else:
            raise ValueError("Unknown similarity type. Choose from 'dot', 'euclidean', or 'cosine'.")
        
        self.center_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.context_embeddings = nn.Embedding(vocab_size, embedding_dim)
        initrange = 0.5 / embedding_dim
        self.center_embeddings.weight.data.uniform_(-initrange, initrange)
        self.context_embeddings.weight.data.zero_()
        
        # Beta is used to scale the Euclidean distance.
        self.beta = nn.Parameter(torch.tensor(1.0))
    
    def forward(self, center_idxs, context_idxs, negative_idxs):
        """
        center_idxs: (B,) tensor of center nodes.
        context_idxs: (B,) tensor of positive context nodes.
        negative_idxs: (B, K) tensor of negative samples.
        """
        center_vecs = self.center_embeddings(center_idxs)         # (B, D)
        pos_context_vecs = self.context_embeddings(context_idxs)    # (B, D)
        neg_context_vecs = self.context_embeddings(negative_idxs)   # (B, K, D)
        
        # Call the compiled C++ extension.
        pos_scores, neg_scores = skipgram_ops.skipgram_forward(
            center_vecs, pos_context_vecs, neg_context_vecs, self.sim_type, self.beta.item()
        )
        return pos_scores, neg_scores

def skipgram_loss(pos_scores, neg_scores):
    """
    Compute loss:
      - For a positive pair: L_pos = -log(sigmoid(score))
      - For negative samples: L_neg = -sum(log(sigmoid(-score)))
    Using F.logsigmoid for numerical stability.
    """
    loss_pos = -F.logsigmoid(pos_scores)
    loss_neg = -torch.sum(F.logsigmoid(-neg_scores), dim=1)
    loss = loss_pos + loss_neg
    return loss.mean()

# %%
from torch.utils.data import DataLoader, Dataset
import time
import random

# (Assume you have implemented functions to generate random walks and skip-gram pairs, and a Dataset class.)
# For illustration, here’s a minimal dummy dataset:
class SkipGramDataset(Dataset):
    def __init__(self, pairs):
        self.pairs = pairs

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        return self.pairs[idx]
##############################################
# Block 5: Training Loop                     #
##############################################

def train_model(G, num_walks = 10, walk_length = 80, 
                window_size = 10, embedding_dim = 128, 
                negative_samples = 5, num_epochs = 1, sim_type = "dot"):
    # Options: "dot", "euclidean", "cosine"
    
    # Use GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)   
    
    # Generate random walks
    start_time = time.time()
    walks = generate_random_walks(G, num_walks, walk_length)
    print("Number of walks:", len(walks))
    print("Example walk:", walks[0])

    pairs = generate_skipgram_pairs(walks, window_size)
    print("Number of positive pairs:", len(pairs))
    print("Example pairs:", pairs[:5])
    print("Skipgram walks and pairs generated in {:.4f} seconds.".format(time.time() - start_time))

    # Create dataset and dataloader
    dataset = SkipGramDataset(pairs)
    # For larger datasets, consider setting num_workers > 0 for parallel data loading.
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True, num_workers=0)

    # Hyperparameters
    vocab_size = G.number_of_nodes()   # Assuming node IDs are 0-indexed.    

    # Initialize model and optimizer
    model = SkipGramModel(vocab_size, embedding_dim, sim_type=sim_type).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    print("\nStarting training...")
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        epoch_start = time.time()
        for center_idxs, context_idxs in dataloader:
            center_idxs = center_idxs.to(device)
            context_idxs = context_idxs.to(device)
            batch_size = center_idxs.size(0)
            # Use device variable to ensure compatibility even if the device is CPU.
            negative_idxs = torch.randint(0, vocab_size, (batch_size, negative_samples), device=device)
            optimizer.zero_grad()
            pos_scores, neg_scores = model(center_idxs, context_idxs, negative_idxs)
            loss = skipgram_loss(pos_scores, neg_scores)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * batch_size
        avg_loss = epoch_loss / len(dataset)
        print(f"Epoch {epoch+1}/{num_epochs} completed in {time.time() - epoch_start:.2f}s, Loss: {avg_loss:.4f}")

    # Save or return the trained model and embeddings as needed.
    return model, device

def evaluate_model(model, device):
    model.eval()
    with torch.no_grad():
        embeddings = model.center_embeddings.weight.cpu().numpy()
    print("Embeddings shape:", embeddings.shape)
    # print("First 5 embeddings:")
    # print(embeddings[:5])
    return embeddings

# %%
##############################################
# Main Function: Run the Training and Eval   #
##############################################

import lfr
def create_network(params={
    "N": 1000,     # number of nodes
    "k": 6,        # average degree
    "maxk": 25,    # maximum degree
    "minc": 25,    # minimum community size
    "maxc": 250,   # maximum community size
    "tau": 2,      # degree exponent
    "tau2": 1.5,   # community size exponent
    "mu": 0.01,     # mixing rate
}):
    ng = lfr.NetworkGenerator()
    data = ng.generate(**params)
    net = data["net"]                  # scipy.csr_sparse matrix
    community_table = data["community_table"]  # pandas DataFrame
    seed = data["seed"]                # Seed value
    return net, community_table, seed


# Create a sample graph (Karate Club)
#G = nx.karate_club_graph()
# Generate the network and the associated community table
A, community_labels, _ = create_network()
G = nx.from_scipy_sparse_array(A)

profiler = cProfile.Profile()
profiler.enable()
model, device = train_model(G, num_walks = 10, walk_length = 80, 
                            window_size = 10, embedding_dim = 128, 
                            negative_samples = 5, num_epochs = 1, sim_type = "euclidean" )

embeddings = evaluate_model(model, device)

profiler.disable()
# Out:
# Using device: cuda
# Number of walks: 10000
# Example walk: [548, 991, 548, 991, 229, 991, 126, 955, 991, 842, 266, 844, 616, 203, 616, 999, 280, 999, 395, 999, 324, 999, 678, 571, 678, 999, 756, 689, 860, 817, 860, 671, 860, 991, 860, 844, 860, 548, 765, 810, 765, 643, 879, 707, 777, 647, 777, 266, 844, 274, 842, 868, 810, 161, 868, 633, 880, 406, 817, 842, 604, 860, 441, 274, 441, 860, 731, 991, 765, 703, 996, 396, 897, 396, 924, 355, 924, 766, 589, 35]
# Number of positive pairs: 14900000
# Example pairs: [(548, 991), (548, 548), (548, 991), (548, 229), (548, 991)]
# Skipgram walks and pairs generated in 8.3594 seconds.
#
# Starting training...
# Epoch 1/1 completed in 971.65s, Loss: 1.2678
# Embeddings shape: (1000, 128)

# %%
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats()
# Out:
#          188664265 function calls (183309504 primitive calls) in 980.483 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    232813  311.819    0.001  311.819    0.001 {method 'run_backward' of 'torch._C._EngineBase' objects}
#    232813   79.033    0.000   79.033    0.000 {built-in method skipgram_ops_v2.skipgram_forward}
#    698439   35.964    0.000   35.964    0.000 {built-in method torch.embedding}
#    698442   30.413    0.000   30.413    0.000 {built-in method torch.tensor}
#    232813   26.757    0.000   62.875    0.000 /tmp/ipykernel_1789051/280362172.py:54(skipgram_loss)
#    465629   21.848    0.000   21.848    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#    698440   21.340    0.000   21.340    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#   1396880   20.704    0.000   20.704    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#         1   19.764   19.764  980.016  980.016 /tmp/ipykernel_1789051/3766849084.py:20(train_model)
#    465626   17.639    0.000   17.639    0.000 {built-in method torch._C._nn.log_sigmoid}
#    232813   13.004    0.000   13.004    0.000 {built-in method torch.randint}
#    465626   12.837    0.000   12.837    0.000 {built-in method torch._foreach_add_}
#    232813   12.234    0.000  106.817    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:485(_multi_tensor_adam)
# 4889080/1396880   12.013    0.000   31.106    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:917(tree_iter)
#    698440   10.619    0.000   10.619    0.000 {built-in method torch._ops.profiler.}
#    232813   10.267    0.000   10.267    0.000 {built-in method torch.sum}
#    232813   10.229    0.000   10.229    0.000 {built-in method torch._foreach_sqrt}
#  14900000    9.562    0.000    9.562    0.000 /tmp/ipykernel_1789051/3766849084.py:14(__getitem__)
#    232813    9.543    0.000    9.543    0.000 {built-in method torch._foreach_lerp_}
#    232813    8.286    0.000   17.849    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:52(<listcomp>)
#    232813    8.213    0.000    8.213    0.000 {method 'mean' of 'torch._C.TensorBase' objects}
#    232813    8.109    0.000    8.109    0.000 {built-in method torch.ones_like}
#    698440    7.333    0.000   59.708    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/profiler.py:757(__exit__)
# 698439/232813    7.282    0.000   49.011    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:118(collate)
#    232813    7.246    0.000   17.514    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/__init__.py:88(_make_grads)
#  14900000    7.192    0.000    9.749    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:206(<genexpr>)
#    232813    7.004    0.000   35.548    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:939(zero_grad)
#    232813    6.905    0.000  196.955    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:473(wrapper)
#    232813    6.748    0.000    6.748    0.000 {built-in method torch._foreach_addcmul_}
#    232813    6.713    0.000    6.713    0.000 {built-in method torch._foreach_addcdiv_}
# 931252/232813    6.655    0.000  147.587    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1743(_call_impl)
#    232813    6.213    0.000    6.213    0.000 {built-in method torch._foreach_mul_}
#   4889080    6.080    0.000    7.292    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:681(_is_namedtuple_instance)
#    232813    6.009    0.000    8.268    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:135(_init_group)
#    232813    5.977    0.000    5.977    0.000 {built-in method torch._foreach_div_}
#    232813    5.428    0.000  121.823    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:809(adam)
#    232814    5.186    0.000   11.452    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:335(__iter__)
#    698439    4.981    0.000   19.117    0.000 {built-in method builtins.all}
# 8656794/8656752    4.902    0.000    7.364    0.000 {built-in method builtins.isinstance}
#    232813    4.859    0.000  143.057    0.001 /tmp/ipykernel_1789051/280362172.py:38(forward)
#    232813    4.430    0.000  154.248    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:72(_use_grad)
# 22310394/22310388    4.398    0.000    4.398    0.000 {built-in method builtins.len}
#    232813    4.394    0.000    4.394    0.000 {built-in method torch._C._group_tensors_by_device_and_dtype}
#         1    4.353    4.353    5.864    5.864 /tmp/ipykernel_1789051/1061095639.py:30(generate_skipgram_pairs)
#   4889080    4.291    0.000   11.583    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:692(_get_node_type)
#    465628    4.064    0.000    4.667    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:110(_maybe_set_eval_frame)
#    698440    3.845    0.000    5.643    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/profiler.py:740(__init__)
#    698440    3.824    0.000   26.875    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/profiler.py:751(__enter__)
#    698439    3.682    0.000    3.682    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:184(<genexpr>)
#    931252    3.530    0.000    7.542    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:101(_get_value)
#  14900001    3.468    0.000    6.266    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:176(__iter__)
#    698439    3.287    0.000   42.392    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:189(forward)
#    232814    3.245    0.000  114.387    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:703(__next__)
# 931252/232813    3.212    0.000  148.698    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1735(_wrapped_call_impl)
#   2560943    3.101    0.000    3.936    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/compiler/__init__.py:367(is_compiling)
#   2793760    3.089    0.000   10.599    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:699(_is_leaf)
#   2095318    3.078    0.000    3.078    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/typing.py:271(inner)
#    232813    3.074    0.000  146.346    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:210(step)
#    232813    3.030    0.000  336.602    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#    232813    2.781    0.000  339.616    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_tensor.py:570(backward)
#   1629702    2.779    0.000    2.779    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1915(__getattr__)
#    931264    2.690    0.000    4.854    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:184(__init__)
#    698440    2.533    0.000    3.167    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:466(_dict_flatten)
#    698440    2.386    0.000   35.237    0.000 {built-in method builtins.any}
#    232813    1.993    0.000  314.380    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/graph.py:814(_engine_run_backward)
#    698440    1.974    0.000   51.572    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:946(__call__)
#    232813    1.966    0.000  124.231    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:140(maybe_fallback)
#    698440    1.957    0.000   38.980    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:1000(_must_dispatch_in_python)
#    232813    1.951    0.000   10.557    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:420(_cuda_graph_capture_health_check)
#    698439    1.900    0.000   38.477    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/functional.py:2437(embedding)
#  18260947    1.841    0.000    1.841    0.000 {method 'append' of 'list' objects}
#    232814    1.795    0.000   42.845    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:738(_fn)
#   5354706    1.793    0.000    1.793    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_jit_internal.py:103(is_scripting)
#    698440    1.786    0.000   37.023    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:1224(tree_any)
#    931252    1.734    0.000    1.734    0.000 {built-in method torch._C._get_tracing_state}
#    698440    1.712    0.000   23.052    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:1112(__call__)
#         2    1.688    0.844    1.688    0.844 {built-in method torch.randperm}
#    931264    1.680    0.000    1.680    0.000 {built-in method torch._C._set_grad_enabled}
#    232813    1.583    0.000   12.779    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:113(decorate_context)
#    232813    1.536    0.000    7.551    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:167(_default_to_fused_or_foreach)
#    232814    1.496    0.000    2.409    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/os.py:674(__getitem__)
#    232813    1.493    0.000    1.493    0.000 {built-in method torch._C._cuda_isCurrentStreamCapturing}
#    232813    1.433    0.000    6.129    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:684(<listcomp>)
#   1396880    1.255    0.000    1.255    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:438(_tuple_flatten)
#    232813    1.243    0.000   69.056    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:47(fetch)
#    698440    1.202    0.000    1.745    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:1002(<lambda>)
#    232814    1.170    0.000   82.280    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:762(_next_data)
#         2    1.110    0.555    1.110    0.555 {method 'tolist' of 'torch._C.TensorBase' objects}
#    465632    1.058    0.000    2.040    0.000 {built-in method _abc._abc_instancecheck}
#    232819    0.993    0.000    1.068    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:75(__init__)
#         1    0.978    0.978    2.495    2.495 /tmp/ipykernel_1789051/1061095639.py:5(generate_random_walks)
#    232813    0.977    0.000   24.940    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:211(<listcomp>)
#   1396896    0.961    0.000    0.961    0.000 {built-in method torch.is_grad_enabled}
#    232813    0.895    0.000    2.952    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:146(clone)
#    232814    0.879    0.000   43.933    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_compile.py:22(inner)
#    232819    0.864    0.000    2.093    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:80(__enter__)
#    465626    0.846    0.000    0.846    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#    232814    0.824    0.000    5.760    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/__init__.py:116(is_available)
#    232813    0.788    0.000   49.799    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:337(default_collate)
#    232819    0.782    0.000    0.989    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:154(__new__)
#    465626    0.775    0.000    0.775    0.000 {built-in method torch.is_complex}
#    232814    0.757    0.000    3.166    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/_collections_abc.py:760(get)
#    232813    0.755    0.000    0.755    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#    465626    0.753    0.000   22.791    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:304(collate_int_fn)
#    232813    0.744    0.000    3.590    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:687(<listcomp>)
#    931260    0.734    0.000    0.734    0.000 {built-in method builtins.getattr}
#    232813    0.702    0.000   13.772    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:507(_group_tensors_by_device_and_dtype)
#    232813    0.698    0.000    0.698    0.000 {built-in method torch._C._are_functorch_transforms_active}
#    232813    0.648    0.000    0.781    0.000 {built-in method _abc._abc_subclasscheck}
#    698441    0.614    0.000    0.614    0.000 {built-in method torch._C._has_torch_function_variadic}
#    232814    0.614    0.000    4.247    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/__init__.py:112(_nvml_based_avail)
#    698439    0.584    0.000    0.705    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:857(<genexpr>)
#    232813    0.569    0.000    0.569    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/logging/__init__.py:1675(getEffectiveLevel)
#    931257    0.547    0.000    0.547    0.000 {built-in method builtins.hasattr}
#    232819    0.533    0.000    1.393    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:84(__exit__)
#    232814    0.529    0.000    0.913    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/os.py:754(encode)
#   1629698    0.518    0.000    0.518    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/typing.py:1375(cast)
#    232813    0.517    0.000    0.867    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:109(_stack_if_compiling)
#    698440    0.511    0.000    0.511    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#    973787    0.510    0.000    0.510    0.000 {method 'values' of 'dict' objects}
#    232814    0.467    0.000    3.633    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/os.py:771(getenv)
#         1    0.465    0.465  980.481  980.481 /tmp/ipykernel_1789051/4253061705.py:32(<module>)
#    232814    0.464    0.000    0.464    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:152(_callback_from_stance)
#    799990    0.443    0.000    0.632    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/random.py:237(_randbelow_with_getrandbits)
#    232813    0.439    0.000    1.124    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_foreach_utils.py:12(_get_fused_kernels_supported_devices)
#    465632    0.421    0.000    2.461    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/abc.py:117(__instancecheck__)
#    465640    0.412    0.000    0.676    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_tensor.py:1166(__hash__)
#    465628    0.408    0.000    0.408    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#    465633    0.402    0.000   11.854    0.000 {built-in method builtins.next}
#    931257    0.401    0.000    0.401    0.000 {method 'values' of 'collections.OrderedDict' objects}
#    232813    0.380    0.000    0.380    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:691(<listcomp>)
#    232813    0.364    0.000    4.758    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_foreach_utils.py:32(_group_tensors_by_device_and_dtype)
#    232813    0.350    0.000    0.350    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/__init__.py:232(_tensor_or_tensors_to_tuple)
#    232813    0.347    0.000    0.347    0.000 {method 'numel' of 'torch._C.TensorBase' objects}
#    790000    0.346    0.000    1.033    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/random.py:343(choice)
#    232813    0.309    0.000    0.309    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:693(<listcomp>)
#    232814    0.306    0.000   12.054    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:697(_next_index)
#    698440    0.302    0.000    0.302    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/jit/__init__.py:128(annotate)
#    232814    0.301    0.000    0.301    0.000 {method 'encode' of 'str' objects}
#    232813    0.290    0.000    0.451    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#    465698    0.285    0.000    0.285    0.000 {method 'get' of 'dict' objects}
#    232814    0.275    0.000    0.435    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/__init__.py:107(_is_compiled)
#    783508    0.273    0.000    0.273    0.000 {method 'keys' of 'dict' objects}
#    465640    0.264    0.000    0.264    0.000 {built-in method builtins.id}
#    232814    0.255    0.000    0.255    0.000 {built-in method torch._C._cuda_getDeviceCount}
#    790000    0.245    0.000    0.326    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/graph.py:1315(neighbors)
#    232813    0.243    0.000    1.737    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/graphs.py:25(is_current_stream_capturing)
#    232813    0.233    0.000    0.233    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/backends/cuda/__init__.py:38(is_built)
#    232813    0.232    0.000    0.232    0.000 {built-in method torch._C._has_torch_function_unary}
#    465626    0.230    0.000    0.230    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/decorators.py:198(graph_break)
#    232819    0.207    0.000    0.207    0.000 {built-in method __new__ of type object at 0x556d7599f380}
#    232813    0.201    0.000    0.982    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/abc.py:121(__subclasscheck__)
#    800000    0.196    0.000    0.208    0.000 {built-in method builtins.max}
#   1022816    0.196    0.000    0.196    0.000 {built-in method builtins.iter}
#    465628    0.195    0.000    0.195    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_utils_internal.py:174(justknobs_check)
#    465628    0.190    0.000    0.190    0.000 {built-in method torch._C._dynamo.eval_frame.set_skip_guard_eval_unsafe}
#    232814    0.181    0.000    0.181    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:189(_is_skip_guard_eval_unsafe_stance)
#    800000    0.136    0.000    0.136    0.000 {built-in method builtins.min}
#    232813    0.133    0.000    0.133    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/_collections_abc.py:315(__subclasshook__)
#   1223348    0.118    0.000    0.118    0.000 {method 'getrandbits' of '_random.Random' objects}
#    232813    0.098    0.000    0.098    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:459(_optimizer_step_code)
#     42534    0.072    0.000    0.199    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#    799990    0.071    0.000    0.071    0.000 {method 'bit_length' of 'int' objects}
#     21267    0.045    0.000    0.070    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#     21267    0.034    0.000    0.043    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1388(enumerate)
#    170136    0.025    0.000    0.025    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1109(ident)
#     21298    0.003    0.000    0.003    0.000 {method '__exit__' of '_thread.RLock' objects}
#        10    0.003    0.000    0.010    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/random.py:348(shuffle)
#         2    0.002    0.001    0.002    0.001 {method 'normal_' of 'torch._C.TensorBase' objects}
#         1    0.001    0.001    0.001    0.001 {method 'uniform_' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cpu' of 'torch._C.TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method torch.empty}
#         4    0.000    0.000    0.000    0.000 {built-in method torch.zeros_like}
#        30    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 {method 'zero_' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/zmq/sugar/socket.py:632(send)
#         9    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        25    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1932(__setattr__)
#         1    0.000    0.000    0.004    0.004 /tmp/ipykernel_1789051/280362172.py:7(__init__)
#       3/1    0.000    0.000    0.001    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:900(_apply)
#         3    0.000    0.000    0.000    0.000 {built-in method _make_subclass}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:237(__init__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:476(__init__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:259(schedule)
#        30    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:505(parent_header)
#         1    0.000    0.000    0.001    0.001 /tmp/ipykernel_1789051/3766849084.py:74(evaluate_model)
#         2    0.000    0.000    0.003    0.002 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:133(__init__)
#         2    0.000    0.000    0.002    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/init.py:20(_no_grad_normal_)
#        22    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/parameter.py:10(__instancecheck__)
#         5    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#        30    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         1    0.000    0.000    0.000    0.000 {method 'numpy' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000  980.482  326.827 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:1011(add_param_group)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:349(__init__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:632(__init__)
#        30    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#        30    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#     21/20    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:461(__setattr__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:584(register_parameter)
#         2    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C.TensorBase' objects}
#        20    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/parameter.py:216(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/codeop.py:142(__call__)
#       3/1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2824(train)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.set_vital}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/traitlets/traitlets.py:676(__get__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1255(user_global_ns)
#        10    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2728(named_children)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:86(__init__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/functools.py:973(__get__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1133(is_alive)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:905(compute_should_use_set_data)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:147(__init__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2588(_named_members)
#         3    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1320(convert)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:169(num_samples)
#         1    0.000    0.000    0.001    0.001 /tmp/ipykernel_1789051/4253061705.py:36(<module>)
#        10    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2719(children)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/traitlets/traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:35(__init__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/parameter.py:40(__new__)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1789051/3766849084.py:8(__init__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:1273(is_initialized)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:74(create_fetcher)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:725(WORLD)
#         2    0.000    0.000    0.002    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:180(reset_parameters)
#         3    0.000    0.000    0.000    0.000 {built-in method torch._has_compatible_shallow_copy_type}
#         3    0.000    0.000  980.482  326.827 {built-in method builtins.exec}
#         2    0.000    0.000    0.002    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/init.py:169(normal_)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:97(_get_distributed_settings)
#         1    0.000    0.000    0.001    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1216(to)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1789051/4253061705.py:38(<module>)
#         6    0.000    0.000    0.000    0.000 /tmp/ipykernel_1789051/3766849084.py:11(__len__)
#         6    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:741(__init__)
#       8/4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2775(named_modules)
#        49    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        30    0.000    0.000    0.000    0.000 {method 'get' of 'ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:417(_get_iterator)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._nn._parse_to}
#         4    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2846(eval)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1066(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3466(compare)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:114(__enter__)
#        42    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x7b8d13ec2700}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:123(__exit__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:261(helper)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:478(__iter__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_python_dispatch.py:368(is_traceable_wrapper_subclass)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2633(named_parameters)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:310(__init__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:600(default_pg)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/graph.py:732(nodes)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:524(_patch_step_function)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:216(_get_scalar_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#         5    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1933(remove_from)
#        10    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2608(parameters)
#         4    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:428(multiprocessing_context)
#        10    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         3    0.000    0.000    0.000    0.000 {method 'is_floating_point' of 'torch._C.TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:536(is_set)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/graph.py:825(number_of_nodes)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:178(__init__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2658(<lambda>)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:182(__len__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:185(__iter__)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:184(_fill_padding_idx_with_zero)
#         2    0.000    0.000    0.000    0.000 {built-in method torch.get_default_dtype}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/__init__.py:14(is_available)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:541(check_worker_number_rationality)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/__future__.py:68(get_swap_module_params_on_conversion)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/__future__.py:25(get_overwrite_module_params_on_conversion)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:493(_auto_collation)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:497(_index_sampler)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:205(__call__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
