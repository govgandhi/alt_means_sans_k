# %% [markdown]
# I guess autograd is magic. Our goal is to try to optimize this algorithm that does Node2Vec but has modifications to use dot similarity or cosine or Euclidean distance. This algorithm is nowhere close to matching embcom times. Currently, the algorithm takes 16 mins to embed a 1000 node lfr network, node2vec from gensim takes 5 seconds :(((
#
# How to speed this up?

# %%
import time
import random
import numpy as np
import networkx as nx

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import lfr # from https://github.com/skojaku/community-detection-via-neural-embedding/tree/master
import sys
import cProfile, pstats

# %%
##############################################
# Block 1: Setup and Random Walk Generation  #
##############################################


def generate_random_walks(G, num_walks=10, walk_length=10):
    """
    Generate random walks over the graph G.
    This needs optimization but we've got bigger fish to fry. 
    Sampling pairs from random walks take 5 seconds out of the 18 minutes.
    """
    walks = []
    nodes = list(G.nodes())
    for _ in range(num_walks):
        random.shuffle(nodes)
        for node in nodes:
            walk = [node]
            for i in range(walk_length - 1):
                cur = walk[-1]
                neighbors = list(G.neighbors(cur))
                if len(neighbors) == 0:
                    break
                walk.append(random.choice(neighbors))
            walks.append(walk)
    return walks

##############################################
# Block 2: Generating SkipGram Pairs         #
##############################################

def generate_skipgram_pairs(walks, window_size=2):
    """
    For each walk, generate (center, context) pairs using a sliding window.
    Consider profiling this block using line_profiler if walks or window_size are large.
    """
    pairs = []
    for walk in walks:
        L = len(walk)
        for i, center in enumerate(walk):
            start = max(0, i - window_size)
            end = min(L, i + window_size + 1)
            for j in range(start, end):
                if i == j:
                    continue
                pairs.append((center, walk[j]))
    return pairs

##############################################
# Block 3: Dataset and DataLoader            #
##############################################

class SkipGramDataset(Dataset):
    def __init__(self, pairs):
        self.pairs = pairs

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        center, context = self.pairs[idx]
        return center, context

##############################################
# Block 4: SkipGram Model and Loss Function    #
##############################################

class SkipGramModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, sim_type="dot"):
        """
        Parameters:
          vocab_size: int – number of nodes.
          embedding_dim: int – embedding dimensionality.
          sim_type: str – similarity measure; options: "dot", "euclidean", "cosine".
        """
        super(SkipGramModel, self).__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.sim_type = sim_type.lower()
        self.center_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.context_embeddings = nn.Embedding(vocab_size, embedding_dim)
        initrange = 0.5 / embedding_dim
        self.center_embeddings.weight.data.uniform_(-initrange, initrange)
        self.context_embeddings.weight.data.zero_()
        
        # Scaling factor for Euclidean distances, rn at just 1
        self.beta = nn.Parameter(torch.tensor(1.0))  

    def forward(self, center_idxs, context_idxs, negative_idxs):
        """
        center_idxs: (B,) tensor for center nodes.
        context_idxs: (B,) tensor for positive context nodes.
        negative_idxs: (B, K) tensor for negative samples.
        Returns:
          pos_scores: (B,) tensor of scores for positive pairs.
          neg_scores: (B, K) tensor of scores for negative pairs.
        """
        center_vecs = self.center_embeddings(center_idxs)         # (B, D)
        pos_context_vecs = self.context_embeddings(context_idxs)    # (B, D)
        neg_context_vecs = self.context_embeddings(negative_idxs)   # (B, K, D)
        
        # Compute positive pair scores based on similarity type.
        if self.sim_type == "dot":
            pos_scores = torch.sum(center_vecs * pos_context_vecs, dim=1)
        elif self.sim_type == "euclidean":
            pos_scores = -torch.norm(center_vecs - pos_context_vecs, dim=1) * self.beta
        elif self.sim_type == "cosine":
            pos_scores = F.cosine_similarity(center_vecs, pos_context_vecs, dim=1)
        else:
            raise ValueError("Unknown similarity type. Choose from 'dot', 'euclidean', or 'cosine'.")

        # Compute negative pair scores.
        if self.sim_type == "dot":
            neg_scores = torch.bmm(neg_context_vecs, center_vecs.unsqueeze(2)).squeeze(2)  # (B, K)
        elif self.sim_type == "euclidean":
            neg_scores = -torch.norm(center_vecs.unsqueeze(1) - neg_context_vecs, dim=2)  # (B, K)
        elif self.sim_type == "cosine":
            neg_scores = F.cosine_similarity(center_vecs.unsqueeze(1).expand_as(neg_context_vecs), neg_context_vecs, dim=2)
        return pos_scores, neg_scores

def skipgram_loss(pos_scores, neg_scores):
    """
    Compute loss:
      - For a positive pair: L_pos = -log(sigmoid(score))
      - For negative samples: L_neg = -sum(log(sigmoid(-score)))
    Optimization tip: You can use F.logsigmoid for numerical stability.
    """
    loss_pos = -F.logsigmoid(pos_scores)
    loss_neg = -torch.sum(F.logsigmoid(-neg_scores), dim=1)
    loss = loss_pos + loss_neg
    return loss.mean()

##############################################
# Block 5: Training Loop                     #
##############################################

def train_model(G, num_walks = 10, walk_length = 10, 
                window_size = 2, embedding_dim = 128, 
                negative_samples = 5, num_epochs = 5, sim_type = "dot"):
    
    '''
    Options for sim_type: "dot", "euclidean", "cosine"
    loss.backward automatically calculates gradients for any form of similarity
    function that we give it! Which makes it easier to modify node2vec to use 
    Euclidean similarity or anything else
    '''
    
    # Use GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)

   
   
    
    # Generate random walks
    start_time = time.time()
    walks = generate_random_walks(G, num_walks, walk_length)
    print("Number of walks:", len(walks))
    print("Example walk:", walks[0])



    pairs = generate_skipgram_pairs(walks, window_size)
    print("Number of positive pairs:", len(pairs))
    print("Example pairs:", pairs[:5])
    print("Skipgram walks and pairs generated in {:.4f} seconds.".format(time.time() - start_time))

    # Create dataset and dataloader
    dataset = SkipGramDataset(pairs)
    # For larger datasets, consider setting num_workers > 0 for parallel data loading.
    dataloader = DataLoader(dataset, batch_size=64, shuffle=True, num_workers=0)

    

    # Hyperparameters
    vocab_size = G.number_of_nodes()   # Assuming node IDs are 0-indexed.
    

    # Initialize model and optimizer
    model = SkipGramModel(vocab_size, embedding_dim, sim_type=sim_type).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    print("\nStarting training...")
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        epoch_start = time.time()
        for center_idxs, context_idxs in dataloader:
            center_idxs = center_idxs.to(device)
            context_idxs = context_idxs.to(device)
            batch_size = center_idxs.size(0)
            # Use device variable to ensure compatibility even if the device is CPU.
            negative_idxs = torch.randint(0, vocab_size, (batch_size, negative_samples), device=device)
            optimizer.zero_grad()
            pos_scores, neg_scores = model(center_idxs, context_idxs, negative_idxs)
            loss = skipgram_loss(pos_scores, neg_scores)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * batch_size
        avg_loss = epoch_loss / len(dataset)
        print(f"Epoch {epoch+1}/{num_epochs} completed in {time.time() - epoch_start:.2f}s, Loss: {avg_loss:.4f}")

    # Save or return the trained model and embeddings as needed.
    return model, device

##############################################
# Block 6: Evaluating and Extracting         #
#         Embeddings                         #
##############################################

def evaluate_model(model, device):
    model.eval()
    with torch.no_grad():
        embeddings = model.center_embeddings.weight.cpu().numpy()
    return embeddings

# %%
##############################################
# Main Function: Run the Training and Eval   #
##############################################

import lfr
def create_network(params={
    "N": 1000,     # number of nodes
    "k": 6,        # average degree
    "maxk": 25,    # maximum degree
    "minc": 25,    # minimum community size
    "maxc": 250,   # maximum community size
    "tau": 2,      # degree exponent
    "tau2": 1.5,   # community size exponent
    "mu": 0.01,     # mixing rate
}):
    ng = lfr.NetworkGenerator()
    data = ng.generate(**params)
    net = data["net"]                  # scipy.csr_sparse matrix
    community_table = data["community_table"]  # pandas DataFrame
    seed = data["seed"]                # Seed value
    return net, community_table, seed


# Create a sample graph (Karate Club)

G = nx.karate_club_graph() # Try this for faster analysis

# A, community_labels, _ = create_network()
# G = nx.from_scipy_sparse_array(A)

#-----------------------
profiler = cProfile.Profile()
profiler.enable()

#-----------------------

model, device = train_model(G, num_walks = 10, walk_length = 40, 
                            window_size = 6, embedding_dim = 64, 
                            negative_samples = 5, num_epochs = 3, sim_type = "euclidean" )

embeddings = evaluate_model(model, device)

#-----------------------
profiler.disable()
# Out:
# Using device: cuda
# Number of walks: 340
# Example walk: [22, 32, 2, 28, 2, 7, 2, 7, 2, 3, 7, 3, 12, 0, 13, 2, 8, 33, 13, 33, 18, 32, 2, 28, 33, 28, 2, 3, 2, 13, 1, 13, 3, 13, 3, 12, 3, 7, 3, 13]
# Number of positive pairs: 148920
# Example pairs: [(22, 32), (22, 2), (22, 28), (22, 2), (22, 7)]
# Skipgram walks and pairs generated in 0.1649 seconds.
#
# Starting training...
# Epoch 1/3 completed in 6.94s, Loss: 0.7099
# Epoch 2/3 completed in 11.01s, Loss: 0.0061
# Epoch 3/3 completed in 9.38s, Loss: 0.0012

# %%
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats()
# Out:
#          5478538 function calls (5317895 primitive calls) in 30.317 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      6981    9.512    0.001    9.512    0.001 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      6981    1.472    0.000    4.271    0.001 /tmp/ipykernel_1795993/3812967147.py:88(forward)
#     20943    1.106    0.000    1.106    0.000 {built-in method torch.embedding}
#     20947    0.948    0.000    0.948    0.000 {built-in method torch.tensor}
#     13962    0.793    0.000    0.793    0.000 {built-in method torch._C._linalg.linalg_vector_norm}
#      6981    0.762    0.000    1.824    0.000 /tmp/ipykernel_1795993/3812967147.py:120(skipgram_loss)
#     13965    0.674    0.000    0.674    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#     20946    0.665    0.000    0.665    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#         1    0.576    0.576   30.308   30.308 /tmp/ipykernel_1795993/3812967147.py:136(train_model)
#     13962    0.508    0.000    0.508    0.000 {built-in method torch._C._nn.log_sigmoid}
#     13962    0.415    0.000    0.415    0.000 {built-in method torch._foreach_add_}
#      6981    0.402    0.000    0.402    0.000 {built-in method torch.randint}
#     48873    0.394    0.000    0.394    0.000 {method 'item' of 'torch._C.TensorBase' objects}
# 146622/41892    0.386    0.000    0.999    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:917(tree_iter)
#      6981    0.382    0.000    3.517    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:485(_multi_tensor_adam)
#      6981    0.348    0.000    0.348    0.000 {built-in method torch._foreach_sqrt}
#     20946    0.322    0.000    0.322    0.000 {built-in method torch._ops.profiler.}
#    446760    0.314    0.000    0.314    0.000 /tmp/ipykernel_1795993/3812967147.py:59(__getitem__)
#      6981    0.303    0.000    0.303    0.000 {built-in method torch._foreach_lerp_}
#      6981    0.299    0.000    0.299    0.000 {built-in method torch.sum}
#     13962    0.279    0.000    1.099    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/functional.py:1676(norm)
#      6981    0.268    0.000    0.582    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:52(<listcomp>)
#      6981    0.260    0.000    1.157    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:939(zero_grad)
#      6981    0.254    0.000    0.254    0.000 {method 'mean' of 'torch._C.TensorBase' objects}
#      6981    0.251    0.000    0.346    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:135(_init_group)
#      6981    0.250    0.000    0.250    0.000 {built-in method torch.ones_like}
#      6981    0.236    0.000    6.477    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:473(wrapper)
#      6981    0.232    0.000    0.545    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/__init__.py:88(_make_grads)
#     20946    0.232    0.000    1.894    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/profiler.py:757(__exit__)
# 20943/6981    0.232    0.000    1.532    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:118(collate)
#    446760    0.223    0.000    0.301    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:206(<genexpr>)
#      6981    0.218    0.000    0.218    0.000 {built-in method torch._foreach_addcdiv_}
#      6981    0.214    0.000    0.214    0.000 {built-in method torch._foreach_addcmul_}
#      6981    0.193    0.000    0.193    0.000 {built-in method torch._foreach_div_}
#    146622    0.192    0.000    0.232    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:681(_is_namedtuple_instance)
#      6981    0.192    0.000    0.192    0.000 {built-in method torch._foreach_mul_}
# 27924/6981    0.191    0.000    4.393    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1743(_call_impl)
#      6981    0.179    0.000    4.021    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:809(adam)
# 321731/321689    0.171    0.000    0.251    0.000 {built-in method builtins.isinstance}
#      6984    0.165    0.000    0.376    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:335(__iter__)
#     20943    0.160    0.000    0.617    0.000 {built-in method builtins.all}
#     41886    0.150    0.000    0.324    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:101(_get_value)
#      6981    0.146    0.000    0.146    0.000 {built-in method torch._C._group_tensors_by_device_and_dtype}
# 655227/655213    0.141    0.000    0.141    0.000 {built-in method builtins.len}
#    146622    0.139    0.000    0.371    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:692(_get_node_type)
#      6981    0.132    0.000    5.120    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:72(_use_grad)
#     27924    0.127    0.000    0.127    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:184(<genexpr>)
#     13964    0.127    0.000    0.146    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:110(_maybe_set_eval_frame)
#    446763    0.119    0.000    0.211    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:176(__iter__)
#     20946    0.117    0.000    0.172    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/profiler.py:740(__init__)
#     90753    0.115    0.000    0.144    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/compiler/__init__.py:367(is_compiling)
#      6984    0.115    0.000    3.647    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:703(__next__)
#     20946    0.114    0.000    0.830    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/profiler.py:751(__enter__)
#      6981    0.110    0.000    0.110    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
#     20943    0.109    0.000    1.316    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:189(forward)
# 27924/6981    0.109    0.000    4.427    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1735(_wrapped_call_impl)
#      6981    0.100    0.000    4.875    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:210(step)
#     48878    0.097    0.000    0.097    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1915(__getattr__)
#     83784    0.096    0.000    0.336    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:699(_is_leaf)
#     62832    0.095    0.000    0.095    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/typing.py:271(inner)
#      6981    0.093    0.000   10.280    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/__init__.py:242(backward)
#     20946    0.086    0.000    0.107    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:466(_dict_flatten)
#     27936    0.083    0.000    0.159    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:184(__init__)
#      6981    0.081    0.000   10.367    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_tensor.py:570(backward)
#     20946    0.078    0.000    1.133    0.000 {built-in method builtins.any}
#     20946    0.063    0.000    1.637    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:946(__call__)
#    188496    0.062    0.000    0.062    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_jit_internal.py:103(is_scripting)
#     20946    0.062    0.000    1.253    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:1000(_must_dispatch_in_python)
#      6981    0.062    0.000    4.097    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:140(maybe_fallback)
#      6981    0.061    0.000    0.325    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:420(_cuda_graph_capture_health_check)
#      6981    0.061    0.000    9.590    0.001 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/graph.py:814(_engine_run_backward)
#     27936    0.060    0.000    0.060    0.000 {built-in method torch._C._set_grad_enabled}
#     20943    0.060    0.000    1.185    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/functional.py:2437(embedding)
#      6982    0.059    0.000    1.391    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:738(_fn)
#     20946    0.058    0.000    1.191    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:1224(tree_any)
#     27924    0.055    0.000    0.055    0.000 {built-in method torch._C._get_tracing_state}
#         1    0.052    0.052    0.070    0.070 /tmp/ipykernel_1795993/3812967147.py:31(generate_skipgram_pairs)
#     20946    0.051    0.000    0.716    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:1112(__call__)
#      6981    0.051    0.000    0.252    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:167(_default_to_fused_or_foreach)
#      6981    0.050    0.000    0.241    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:684(<listcomp>)
#         6    0.048    0.008    0.048    0.008 {method 'tolist' of 'torch._C.TensorBase' objects}
#      6982    0.047    0.000    0.076    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/os.py:674(__getitem__)
#      6981    0.047    0.000    0.406    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:113(decorate_context)
#    274220    0.046    0.000    0.046    0.000 {method 'append' of 'list' objects}
#      6981    0.046    0.000    0.046    0.000 {built-in method torch._C._cuda_isCurrentStreamCapturing}
#      6984    0.046    0.000    2.622    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:762(_next_data)
#         6    0.045    0.007    0.045    0.007 {built-in method torch.randperm}
#     41892    0.040    0.000    0.040    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_pytree.py:438(_tuple_flatten)
#      6981    0.038    0.000    2.181    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:47(fetch)
#     20946    0.037    0.000    0.055    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_ops.py:1002(<lambda>)
#     13974    0.034    0.000    0.065    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.034    0.034    0.089    0.089 /tmp/ipykernel_1795993/3812967147.py:6(generate_random_walks)
#      6987    0.033    0.000    0.035    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:75(__init__)
#      6981    0.032    0.000    0.773    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:211(<listcomp>)
#     41904    0.031    0.000    0.031    0.000 {built-in method torch.is_grad_enabled}
#     20943    0.031    0.000    0.031    0.000 {built-in method torch.is_complex}
#      6981    0.028    0.000    0.160    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:687(<listcomp>)
#      6982    0.027    0.000    1.425    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_compile.py:22(inner)
#      6982    0.027    0.000    0.182    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/__init__.py:116(is_available)
#      6981    0.027    0.000    0.094    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:146(clone)
#      6987    0.025    0.000    0.032    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:154(__new__)
#     13962    0.025    0.000    0.025    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#      6987    0.025    0.000    0.066    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:80(__enter__)
#      6981    0.024    0.000    1.556    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:337(default_collate)
#      6982    0.024    0.000    0.100    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/_collections_abc.py:760(get)
#     13962    0.024    0.000    0.706    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:304(collate_int_fn)
#      6981    0.023    0.000    0.439    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:507(_group_tensors_by_device_and_dtype)
#     27924    0.023    0.000    0.029    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:857(<genexpr>)
#      6981    0.023    0.000    0.023    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#      6981    0.023    0.000    0.023    0.000 {built-in method torch._C._are_functorch_transforms_active}
#     20945    0.020    0.000    0.020    0.000 {built-in method torch._C._has_torch_function_variadic}
#      6981    0.020    0.000    0.024    0.000 {built-in method _abc._abc_subclasscheck}
#     20943    0.020    0.000    0.020    0.000 {built-in method torch._C._has_torch_function_unary}
#      6982    0.020    0.000    0.134    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/__init__.py:112(_nvml_based_avail)
#     27932    0.019    0.000    0.019    0.000 {built-in method builtins.getattr}
#     27931    0.017    0.000    0.017    0.000 {built-in method builtins.hasattr}
#      6982    0.017    0.000    0.029    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/os.py:754(encode)
#     20958    0.017    0.000    0.028    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_tensor.py:1166(__hash__)
#      6982    0.017    0.000    0.017    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:152(_callback_from_stance)
#      6981    0.017    0.000    0.017    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/logging/__init__.py:1675(getEffectiveLevel)
#     13590    0.017    0.000    0.024    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/random.py:237(_randbelow_with_getrandbits)
#     28347    0.016    0.000    0.016    0.000 {method 'values' of 'dict' objects}
#     48874    0.016    0.000    0.016    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/typing.py:1375(cast)
#     20946    0.016    0.000    0.016    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#      6981    0.016    0.000    0.027    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:109(_stack_if_compiling)
#      6981    0.015    0.000    0.015    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:691(<listcomp>)
#      6987    0.014    0.000    0.042    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:84(__exit__)
#     13974    0.014    0.000    0.079    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/abc.py:117(__instancecheck__)
#      6982    0.014    0.000    0.114    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/os.py:771(getenv)
#     13964    0.013    0.000    0.013    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#      6981    0.013    0.000    0.033    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_foreach_utils.py:12(_get_fused_kernels_supported_devices)
#     27929    0.013    0.000    0.013    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     13971    0.013    0.000    0.389    0.000 {built-in method builtins.next}
#     13260    0.013    0.000    0.038    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/random.py:343(choice)
#      6981    0.013    0.000    0.158    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_foreach_utils.py:32(_group_tensors_by_device_and_dtype)
#      6981    0.012    0.000    0.012    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:693(<listcomp>)
#      6981    0.011    0.000    0.011    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/autograd/__init__.py:232(_tensor_or_tensors_to_tuple)
#     20958    0.011    0.000    0.011    0.000 {built-in method builtins.id}
#      6981    0.010    0.000    0.010    0.000 {method 'numel' of 'torch._C.TensorBase' objects}
#      6984    0.010    0.000    0.395    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:697(_next_index)
#     20946    0.009    0.000    0.009    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/jit/__init__.py:128(annotate)
#      6982    0.009    0.000    0.009    0.000 {method 'encode' of 'str' objects}
#      6981    0.009    0.000    0.014    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#      6982    0.009    0.000    0.014    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/__init__.py:107(_is_compiled)
#     14032    0.009    0.000    0.009    0.000 {method 'get' of 'dict' objects}
#     21786    0.009    0.000    0.009    0.000 {method 'keys' of 'dict' objects}
#     13260    0.008    0.000    0.011    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/graph.py:1315(neighbors)
#      6982    0.008    0.000    0.008    0.000 {built-in method torch._C._cuda_getDeviceCount}
#      6981    0.008    0.000    0.053    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/cuda/graphs.py:25(is_current_stream_capturing)
#         1    0.007    0.007   30.316   30.316 /tmp/ipykernel_1795993/2481857921.py:37(<module>)
#     13962    0.007    0.000    0.007    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/decorators.py:198(graph_break)
#      6981    0.007    0.000    0.031    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/abc.py:121(__subclasscheck__)
#     20248    0.007    0.000    0.007    0.000 {built-in method builtins.iter}
#     13964    0.006    0.000    0.006    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_utils_internal.py:174(justknobs_check)
#      6987    0.006    0.000    0.006    0.000 {built-in method __new__ of type object at 0x626a9e326380}
#      6981    0.006    0.000    0.006    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/backends/cuda/__init__.py:38(is_built)
#      6982    0.006    0.000    0.006    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:189(_is_skip_guard_eval_unsafe_stance)
#     13964    0.006    0.000    0.006    0.000 {built-in method torch._C._dynamo.eval_frame.set_skip_guard_eval_unsafe}
#     23225    0.004    0.000    0.004    0.000 {method 'getrandbits' of '_random.Random' objects}
#      6981    0.004    0.000    0.004    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/_collections_abc.py:315(__subclasshook__)
#     13600    0.003    0.000    0.003    0.000 {built-in method builtins.max}
#      6981    0.003    0.000    0.003    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:459(_optimizer_step_code)
#     13590    0.003    0.000    0.003    0.000 {method 'bit_length' of 'int' objects}
#     13600    0.002    0.000    0.002    0.000 {built-in method builtins.min}
#         8    0.001    0.000    0.001    0.000 {built-in method torch.empty}
#         4    0.001    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/zmq/sugar/socket.py:632(send)
#       420    0.001    0.000    0.002    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#       210    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#       210    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1388(enumerate)
#        30    0.000    0.000    0.002    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:655(write)
#      1680    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1109(ident)
#        10    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/random.py:348(shuffle)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        10    0.000    0.000    0.002    0.000 {built-in method builtins.print}
#        25    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1932(__setattr__)
#         1    0.000    0.000    0.000    0.000 {method 'cpu' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:632(__init__)
#         6    0.000    0.000    0.000    0.000 {built-in method torch.zeros_like}
#         4    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:259(schedule)
#         6    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'normal_' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:476(__init__)
#         3    0.000    0.000   30.316   10.105 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#       240    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#       3/1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:900(_apply)
#         1    0.000    0.000    0.000    0.000 {method 'numpy' of 'torch._C.TensorBase' objects}
#        30    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:505(parent_header)
#         1    0.000    0.000    0.001    0.001 /tmp/ipykernel_1795993/3812967147.py:68(__init__)
#         8    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:169(num_samples)
#        30    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1795993/3812967147.py:209(evaluate_model)
#        30    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/codeop.py:142(__call__)
#        22    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/parameter.py:10(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 {method 'uniform_' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _make_subclass}
#        30    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:237(__init__)
#         3    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:741(__init__)
#         3    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:417(_get_iterator)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:86(__init__)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:133(__init__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1133(is_alive)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:1011(add_param_group)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:97(_get_distributed_settings)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:1273(is_initialized)
#        10    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2728(named_children)
#       3/1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2824(train)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:349(__init__)
#     21/20    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:461(__setattr__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2588(_named_members)
#        20    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/parameter.py:216(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/traitlets/traitlets.py:676(__get__)
#         5    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/iostream.py:138(_event_pipe)
#        14    0.000    0.000    0.000    0.000 /tmp/ipykernel_1795993/3812967147.py:56(__len__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/traitlets/traitlets.py:629(get)
#        10    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2719(children)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:74(create_fetcher)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/init.py:20(_no_grad_normal_)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1795993/2481857921.py:44(<module>)
#         3    0.000    0.000    0.000    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:584(register_parameter)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:725(WORLD)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1216(to)
#         6    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1795993/2481857921.py:41(<module>)
#         3    0.000    0.000    0.001    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:478(__iter__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1066(_wait_for_tstate_lock)
#        49    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         3    0.000    0.000   30.316   10.105 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1320(convert)
#         4    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        30    0.000    0.000    0.000    0.000 {method 'get' of 'ContextVar' objects}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:114(__enter__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/adam.py:35(__init__)
#       8/4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2775(named_modules)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:123(__exit__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2846(eval)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3466(compare)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/parameter.py:40(__new__)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/contextlib.py:261(helper)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/__init__.py:14(is_available)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:905(compute_should_use_set_data)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1255(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:180(reset_parameters)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:9(__init__)
#        42    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x7ca0b8e92430}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:600(default_pg)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/init.py:169(normal_)
#         3    0.000    0.000    0.000    0.000 {built-in method torch._has_compatible_shallow_copy_type}
#         8    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method 'zero_' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:216(_get_scalar_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.set_vital}
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2608(parameters)
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:147(__init__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2633(named_parameters)
#         5    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1933(remove_from)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/_python_dispatch.py:368(is_traceable_wrapper_subclass)
#        10    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:493(_auto_collation)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._nn._parse_to}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/optim/optimizer.py:524(_patch_step_function)
#        10    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:497(_index_sampler)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:185(__iter__)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:182(__len__)
#         4    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:536(is_set)
#         3    0.000    0.000    0.000    0.000 {method 'is_floating_point' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/sampler.py:310(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/module.py:2658(<lambda>)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/graph.py:825(number_of_nodes)
#         3    0.000    0.000    0.000    0.000 {built-in method torch.get_default_dtype}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1795993/3812967147.py:53(__init__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:428(multiprocessing_context)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/__future__.py:25(get_overwrite_module_params_on_conversion)
#         2    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/nn/modules/sparse.py:184(_fill_padding_idx_with_zero)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:541(check_worker_number_rationality)
#         3    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/__future__.py:68(get_swap_module_params_on_conversion)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/networkx/classes/reportviews.py:205(__call__)
#         1    0.000    0.000    0.000    0.000 /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}

# %%
import embcom


def create_embedding(G, emb_params = {
                                            "window_length": 10,
                                            "walk_length": 40,
                                            "num_walks": 6,
                                            "dim" : 64,
                                        }):
  
    model = embcom.embeddings.Node2Vec(window_length = emb_params['window_length'], walk_length=emb_params['walk_length'], num_walks=emb_params['num_walks'])
            
    net = nx.adjacency_matrix(G).astype(float)
    model.fit(net)
    emb = model.transform(dim=emb_params['dim'])

    return emb

G = nx.karate_club_graph()

start_t = time.time()
emb_p = create_embedding(G)
print("Time in seconds:", time.time() - start_t)
# Out:
# Time in seconds: 0.02255702018737793

# %%
from sklearn.metrics.pairwise import cosine_similarity


def calculate_normalized_embedding_loss(V_a, V_b):
    
    
    def center_embeddings(V):
        # Subtract the mean of each column from the corresponding entries
        return V - np.mean(V, axis=0)

    
    # Step 1: Center both embedding matrices
    V_a_centered = center_embeddings(V_a)
    V_b_centered = center_embeddings(V_b)
    
    # Step 2: Calculate cosine similarity matrices for centered embeddings
    C_a = cosine_similarity(V_a_centered)
    C_b = cosine_similarity(V_b_centered)
    
    # Step 3: Calculate the absolute differences between cosine similarities
    N = V_a.shape[0]
    loss = 0
    
    # Only sum over the upper triangular part of the matrix (i < j)
    for i in range(N):
        for j in range(i+1, N):
            loss += np.abs(C_a[i, j] - C_b[i, j])
    
    # Step 4: Normalize the loss
    normalized_loss = (2 / (N * (N - 1))) * loss
    
    return normalized_loss



loss = calculate_normalized_embedding_loss(emb_p, embeddings)
loss
# Out:
# 0.3451614016445388

# %% [markdown]
# This is the normalized embedding loss between the embeddings generated by the code and by node2vec that uses gensim.
