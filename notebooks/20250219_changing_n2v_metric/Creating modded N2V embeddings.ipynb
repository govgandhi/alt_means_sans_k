# %% [markdown]
# In this notebook, we will use the node2vecs package which was modified in "Final - Modding Sadamori's Torch N2V.ipynb" in the previously timestamped folder. We modified the loss functions to use cosine and Euclidean distances apart from just dot similarity. The autograd function was used to verify our manual jacobian calculations.
# We now generate embeddings through this modified node2vec to suit our needs later. We want to use the embeddings to run clustering with different distance metrics to see if there's something interesting.

# %% [markdown]
# I want to use another set of networks because of some weird aberrations that were happening in low mixing limits in the previous run.

# %%
import os
import numpy as np
import scipy.sparse as sp
import pandas as pd
import pickle
from concurrent.futures import ProcessPoolExecutor, as_completed
from tqdm import tqdm
from node2vecs import TorchNode2Vec

def process_task(task):
    """
    Process a single task: load the network and community table, train embeddings using three similarity metrics,
    and save embeddings, network, and community table to the output directory.
    
    task: tuple (k, run, mu, task_idx)
    """
    k, run, mu, task_idx = task
    # Alternate GPU devices: tasks with even task_idx use cuda:0, odd use cuda:1
    device = f"cuda:{task_idx % 2}"
    
    # Define input and output directories for this k value
    input_base = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_mu_change_10000_{k}_3.0_minc50"
    output_base = f"/nobackup/gogandhi/alt_means_sans_k/data/experiment_n2v_metric_cosine_change_10000_{k}_3.0_minc50"
    
    input_run_dir = os.path.join(input_base, f"Run_{run}")
    output_run_dir = os.path.join(output_base, f"Run_{run}")
    os.makedirs(output_run_dir, exist_ok=True)
    
    mu_str = f"{mu}"
    net_filename = f"net_LFR_n_10000_tau1_3.0_tau2_1.0_mu_{mu_str}_k_{k}_mincomm_50.npz"
    comm_filename = f"community_table_LFR_n_10000_tau1_3.0_tau2_1.0_mu_{mu_str}_k_{k}_mincomm_50.npz"
    
    net_path = os.path.join(input_run_dir, net_filename)
    comm_path = os.path.join(input_run_dir, comm_filename)
    
    if not os.path.exists(net_path):
        print(f"[Task {task_idx}] Network file not found: {net_path}")
        return
    if not os.path.exists(comm_path):
        print(f"[Task {task_idx}] Community file not found: {comm_path}")
        return
    
    # Load the network as a scipy sparse matrix
    try:
        A = sp.load_npz(net_path)
    except Exception as e:
        print(f"[Task {task_idx}] Error loading network file {net_path}: {e}")
        return
    
    # Load the community table; assume it's saved in an npz file
    try:
        community_table = pd.read_csv(comm_path)
        
    except Exception as e:
        print(f"[Task {task_idx}] Error loading community file {comm_path}: {e}")
        return
    
    # Define the similarity metrics to test
    similarity_measures = ["cosine"]
    embeddings_dict = {}
    
    for sim in similarity_measures:
        print(f"[Task {task_idx}] Training model using {sim} similarity for Run {run}, mu {mu_str}, k {k} on {device}...")
        try:
            model = TorchNode2Vec(
                vector_size=64,
                similarity_metric=sim,
                device=device,
                num_workers=1
            )
            model.fit(A)
            emb = model.transform()
            embeddings_dict[sim] = emb
        except Exception as e:
            print(f"[Task {task_idx}] Error training {sim} model for Run {run}, mu {mu_str}, k {k} on {device}: {e}")
            continue
    
    # Save the embeddings dictionary as a pickle file
    out_filename = f"embeddings_LFR_n_10000_tau1_3.0_tau2_1.0_mu_{mu_str}_k_{k}_mincomm_50.pkl"
    out_path = os.path.join(output_run_dir, out_filename)
    try:
        with open(out_path, "wb") as f:
            pickle.dump(embeddings_dict, f)
        print(f"[Task {task_idx}] Saved embeddings to {out_path}")
    except Exception as e:
        print(f"[Task {task_idx}] Error saving embeddings to {out_path}: {e}")
    
    # # Save the network to the output folder
    # network_out_path = os.path.join(output_run_dir, net_filename)
    # try:
    #     sp.save_npz(network_out_path, A)
    #     print(f"[Task {task_idx}] Saved network to {network_out_path}")
    # except Exception as e:
    #     print(f"[Task {task_idx}] Error saving network to {network_out_path}: {e}")
    
    # # Save the community table as a CSV file to the output folder
    # community_out_path = os.path.join(output_run_dir, f"community_table_LFR_n_10000_tau1_3.0_tau2_1.0_mu_{mu_str}_k_{k}_mincomm_50.csv")
    # try:
    #     if not isinstance(community_table, pd.DataFrame):
    #         community_table = pd.DataFrame(community_table)
    #     community_table.to_csv(community_out_path, index=False)
    #     print(f"[Task {task_idx}] Saved community table to {community_out_path}")
    # except Exception as e:
    #     print(f"[Task {task_idx}] Error saving community table to {community_out_path}: {e}")

# Process k values sequentially while parallelizing runs and mu-values
for k in [50]:
    tasks = []
    mu_values = [round(x, 2) for x in np.arange(0.05, 1.01, 0.05)]
    #mu_values = [0.05]
    task_idx = 0
    for run in range(1, 11):
        for mu in mu_values:
            tasks.append((k, run, mu, task_idx))
            task_idx += 1
    
    # Use a ProcessPoolExecutor to run tasks in parallel; adjust max_workers as needed
    # with ProcessPoolExecutor(max_workers=20) as executor:
    #     futures = [executor.submit(process_task, task) for task in tasks]
    #     for _ in tqdm(as_completed(futures), total=len(futures), desc=f"Processing k={k}"):
    #         pass
    with ProcessPoolExecutor(max_workers=20) as executor:
        futures = [executor.submit(process_task, task) for task in tasks]
        # Create a single progress bar instance
        with tqdm(total=len(futures), desc=f"Processing k={k}", miniters=10) as pbar:
            for future in as_completed(futures):
                # Optionally get the result if you need to catch exceptions
                future.result()
                pbar.update(1)
# Out:
# Processing k=50:   0%|                                                                                                         | 0/200 [00:00<?, ?it/s]
# [Task 5] Training model using cosine similarity for Run 1, mu 0.3, k 50 on cuda:1...
# [Task 2] Training model using cosine similarity for Run 1, mu 0.15, k 50 on cuda:0...
# [Task 3] Training model using cosine similarity for Run 1, mu 0.2, k 50 on cuda:1...[Task 14] Training model using cosine similarity for Run 1, mu 0.75, k 50 on cuda:0...[Task 4] Training model using cosine similarity for Run 1, mu 0.25, k 50 on cuda:0...
#
# [Task 7] Training model using cosine similarity for Run 1, mu 0.4, k 50 on cuda:1...[Task 1] Training model using cosine similarity for Run 1, mu 0.1, k 50 on cuda:1...[Task 0] Training model using cosine similarity for Run 1, mu 0.05, k 50 on cuda:0...
#
#
# [Task 8] Training model using cosine similarity for Run 1, mu 0.45, k 50 on cuda:0...
#
# [Task 6] Training model using cosine similarity for Run 1, mu 0.35, k 50 on cuda:0...
# [Task 12] Training model using cosine similarity for Run 1, mu 0.65, k 50 on cuda:0...
# [Task 11] Training model using cosine similarity for Run 1, mu 0.6, k 50 on cuda:1...
# [Task 17] Training model using cosine similarity for Run 1, mu 0.9, k 50 on cuda:1...[Task 15] Training model using cosine similarity for Run 1, mu 0.8, k 50 on cuda:1...
#
# [Task 10] Training model using cosine similarity for Run 1, mu 0.55, k 50 on cuda:0...[Task 19] Training model using cosine similarity for Run 1, mu 1.0, k 50 on cuda:1...
# [Task 18] Training model using cosine similarity for Run 1, mu 0.95, k 50 on cuda:0...
#
# [Task 9] Training model using cosine similarity for Run 1, mu 0.5, k 50 on cuda:1...
# [Task 13] Training model using cosine similarity for Run 1, mu 0.7, k 50 on cuda:1...[Task 16] Training model using cosine similarity for Run 1, mu 0.85, k 50 on cuda:0...
#   6%|██████▎                                                                                           | 2000/31250 [01:36<51:25,  9.48it/s, loss=1.39]Exception in thread Thread-7:
# Traceback (most recent call last):
# Exception in thread   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py", line 980, in _bootstrap_inner
# Thread-7:
#     Traceback (most recent call last):
# self.run()  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
# _threading_Thread_run(self)  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py", line 917, in run
# _threading_Thread_run(self)
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py", line 917, in run
# self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/pin_memory.py", line 59, in _pin_memory_loop
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/pin_memory.py", line 59, in _pin_memory_loop
#         do_one_step()do_one_step()
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/pin_memory.py", line 35, in do_one_step
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/utils/data/_utils/pin_memory.py", line 35, in do_one_step
#         r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/queues.py", line 122, in get
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/queues.py", line 122, in get
#         return _ForkingPickler.loads(res)return _ForkingPickler.loads(res)
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/resource_sharer.py", line 57, in detach
#         with _resource_sharer.get_connection(self._id) as conn:fd = df.detach()
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/resource_sharer.py", line 57, in detach
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/resource_sharer.py", line 86, in get_connection
#         with _resource_sharer.get_connection(self._id) as conn:c = Client(address, authkey=process.current_process().authkey)
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 502, in Client
#
# c = SocketClient(address)  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/resource_sharer.py", line 86, in get_connection
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 630, in SocketClient
#         s.connect(address)c = Client(address, authkey=process.current_process().authkey)
#
# FileNotFoundError  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 508, in Client
# : [Errno 2] No such file or directory
# answer_challenge(c, authkey)
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 757, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#   6%|██████▎                                                                                           | 2000/31250 [01:36<23:36, 20.65it/s, loss=1.39]
# [Task 20] Training model using cosine similarity for Run 2, mu 0.05, k 50 on cuda:0...
#   1%|▊                                                                                                  | 254/31250 [00:03<05:36, 92.13it/s, loss=1.38]Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: <generator object tqdm.__iter__ at 0x7ebe6c7e9120><generator object tqdm.__iter__ at 0x7ebe6c7e6120><generator object tqdm.__iter__ at 0x7ebe6c7e5120><generator object tqdm.__iter__ at 0x7ebe6c7e4120><generator object tqdm.__iter__ at 0x7ebe6c7ea120><generator object tqdm.__iter__ at 0x7ebe6c7e2190><generator object tqdm.__iter__ at 0x7ebe6c7e3120><generator object tqdm.__iter__ at 0x7ebe6c7e5120><generator object tqdm.__iter__ at 0x7ebe6c7e6120><generator object tqdm.__iter__ at 0x7ebe6c7e7120><generator object tqdm.__iter__ at 0x7ebe6c7e6120><generator object tqdm.__iter__ at 0x7ebe6c7e2120><generator object tqdm.__iter__ at 0x7ebe6c7e8120><generator object tqdm.__iter__ at 0x7ebe6c7e3120><generator object tqdm.__iter__ at 0x7ebe6c7e3120><generator object tqdm.__iter__ at 0x7ebe6c7e3120><generator object tqdm.__iter__ at 0x7ebe6c7e3120><generator object tqdm.__iter__ at 0x7ebe6c7e9120>
# <generator object tqdm.__iter__ at 0x7ebe6c7e6120>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Traceback (most recent call last):
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
# Traceback (most recent call last):
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1196, in __iter__
#                                                         self.close()    self.close()                self.close()self.close()self.close()self.close()self.close()self.close()self.close()self.close()self.close()self.close()self.close()self.close()
# self.close()self.close()
# self.close()self.close()self.close()
#
#
#
#
#
#
#
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1275, in close
#   1%|▊                                                                                                  | 263/31250 [00:03<07:23, 69.87it/s, loss=1.38]_decr_instances(self)    self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)
# self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)self._decr_instances(self)
#
# self._decr_instances(self)
# self._decr_instances(self)
#
#
#
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#
#
#
#
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#           File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 696, in _decr_instances
#                                 with cls._lock:                with cls._lock:with cls._lock:            with cls._lock:with cls._lock:with cls._lock:    with cls._lock:with cls._lock:with cls._lock:with cls._lock:with cls._lock:
# with cls._lock:with cls._lock:with cls._lock:
# with cls._lock:
# with cls._lock:with cls._lock:with cls._lock:
#
#
# with cls._lock:
#
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 111, in __enter__
#     self.acquire()self.acquire()self.acquire()self.acquire()
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#                                                                             self.acquire()lock.acquire(*a, **k)self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()self.acquire()lock.acquire(*a, **k)self.acquire()lock.acquire(*a, **k)self.acquire()lock.acquire(*a, **k)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
# KeyboardInterrupt  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
# KeyboardInterrupt  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
# KeyboardInterrupt  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 104, in acquire
# KeyboardInterrupt:                                         :         :             : lock.acquire(*a, **k)
# lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)lock.acquire(*a, **k)
# lock.acquire(*a, **k)lock.acquire(*a, **k)
# lock.acquire(*a, **k)lock.acquire(*a, **k)
# lock.acquire(*a, **k)
#
#
#
#
#
#
#
#
#
#
#
#
#
# KeyboardInterruptKeyboardInterruptKeyboardInterrupt
# KeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterruptKeyboardInterrupt: : : KeyboardInterrupt: : : : : : : : :
# : :
# :
# [Task 21] Training model using cosine similarity for Run 2, mu 0.1, k 50 on cuda:1...
# [Task 22] Training model using cosine similarity for Run 2, mu 0.15, k 50 on cuda:0...
# [Task 23] Training model using cosine similarity for Run 2, mu 0.2, k 50 on cuda:1...
# [Task 25] Training model using cosine similarity for Run 2, mu 0.3, k 50 on cuda:1...
# [Task 24] Training model using cosine similarity for Run 2, mu 0.25, k 50 on cuda:0...[Task 26] Training model using cosine similarity for Run 2, mu 0.35, k 50 on cuda:0...[Task 27] Training model using cosine similarity for Run 2, mu 0.4, k 50 on cuda:1...
#
#
# [Task 28] Training model using cosine similarity for Run 2, mu 0.45, k 50 on cuda:0...
# [Task 30] Training model using cosine similarity for Run 2, mu 0.55, k 50 on cuda:0...
# [Task 32] Training model using cosine similarity for Run 2, mu 0.65, k 50 on cuda:0...[Task 31] Training model using cosine similarity for Run 2, mu 0.6, k 50 on cuda:1...[Task 34] Training model using cosine similarity for Run 2, mu 0.75, k 50 on cuda:0...
# [Task 29] Training model using cosine similarity for Run 2, mu 0.5, k 50 on cuda:1...
#
#
# [Task 33] Training model using cosine similarity for Run 2, mu 0.7, k 50 on cuda:1...[Task 37] Training model using cosine similarity for Run 2, mu 0.9, k 50 on cuda:1...
#
# [Task 35] Training model using cosine similarity for Run 2, mu 0.8, k 50 on cuda:1...[Task 36] Training model using cosine similarity for Run 2, mu 0.85, k 50 on cuda:0...
#
# [Task 40] Training model using cosine similarity for Run 3, mu 0.05, k 50 on cuda:0...[Task 39] Training model using cosine similarity for Run 2, mu 1.0, k 50 on cuda:1...
#
# [Task 38] Training model using cosine similarity for Run 2, mu 0.95, k 50 on cuda:0...
# Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: <function tqdm.__del__ at 0x7ebe40afe4c0><function tqdm.__del__ at 0x7ebe40afe4c0><function tqdm.__del__ at 0x7ebe40afe4c0><function tqdm.__del__ at 0x7ebe40afe4c0><function tqdm.__del__ at 0x7ebe40afe4c0>
# <function tqdm.__del__ at 0x7ebe40afe4c0><function tqdm.__del__ at 0x7ebe40afe4c0>
# Traceback (most recent call last):
#
# Traceback (most recent call last):
#
#
#
#
# Traceback (most recent call last):
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
# Traceback (most recent call last):
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
#         Traceback (most recent call last):
#         self.close()self.close()self.close()self.close()
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
# self.close()  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
#
#
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
# self.close()          File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
#
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
# if self.disable:self.close()
#       File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
#
#
# if self.disable:AttributeError  File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py", line 1267, in close
#
# : AttributeError'tqdm' object has no attribute 'disable':
# 'tqdm' object has no attribute 'disable'
#                     if self.disable:if self.disable:if self.disable:if self.disable:if self.disable:
#
#
#
#
# AttributeErrorAttributeErrorAttributeErrorAttributeErrorAttributeError: : : : : 'tqdm' object has no attribute 'disable''tqdm' object has no attribute 'disable''tqdm' object has no attribute 'disable''tqdm' object has no attribute 'disable''tqdm' object has no attribute 'disable'
# [Task 41] Training model using cosine similarity for Run 3, mu 0.1, k 50 on cuda:1...[Task 43] Training model using cosine similarity for Run 3, mu 0.2, k 50 on cuda:1...
#
# [Task 44] Training model using cosine similarity for Run 3, mu 0.25, k 50 on cuda:0...
# [Task 42] Training model using cosine similarity for Run 3, mu 0.15, k 50 on cuda:0...[Task 45] Training model using cosine similarity for Run 3, mu 0.3, k 50 on cuda:1...
#
# [Task 46] Training model using cosine similarity for Run 3, mu 0.35, k 50 on cuda:0...
# [Task 50] Training model using cosine similarity for Run 3, mu 0.55, k 50 on cuda:0...[Task 49] Training model using cosine similarity for Run 3, mu 0.5, k 50 on cuda:1...[Task 47] Training model using cosine similarity for Run 3, mu 0.4, k 50 on cuda:1...[Task 48] Training model using cosine similarity for Run 3, mu 0.45, k 50 on cuda:0...
# [Task 51] Training model using cosine similarity for Run 3, mu 0.6, k 50 on cuda:1...
#
# [Task 53] Training model using cosine similarity for Run 3, mu 0.7, k 50 on cuda:1...
#
#
# [Task 52] Training model using cosine similarity for Run 3, mu 0.65, k 50 on cuda:0...
# [Task 55] Training model using cosine similarity for Run 3, mu 0.8, k 50 on cuda:1...[Task 54] Training model using cosine similarity for Run 3, mu 0.75, k 50 on cuda:0...
#
# [Task 59] Training model using cosine similarity for Run 3, mu 1.0, k 50 on cuda:1...[Task 56] Training model using cosine similarity for Run 3, mu 0.85, k 50 on cuda:0...
#
# [Task 57] Training model using cosine similarity for Run 3, mu 0.9, k 50 on cuda:1...
# [Task 60] Training model using cosine similarity for Run 4, mu 0.05, k 50 on cuda:0...
# [Task 58] Training model using cosine similarity for Run 3, mu 0.95, k 50 on cuda:0...
# [Task 54] Error training cosine model for Run 3, mu 0.75, k 50 on cuda:0: CPUDispatcher(<function _get_center_double_context_windows at 0x7ebd664cbdc0>) returned a result with an error set
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7ebe70bc7460>>
# Traceback (most recent call last):
#   File "/nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# [Task 54] Saved embeddings to /nobackup/gogandhi/alt_means_sans_k/data/experiment_n2v_metric_cosine_change_10000_50_3.0_minc50/Run_3/embeddings_LFR_n_10000_tau1_3.0_tau2_1.0_mu_0.75_k_50_mincomm_50.pkl
# [Task 61] Training model using cosine similarity for Run 4, mu 0.1, k 50 on cuda:1...
# [Task 55] Error training cosine model for Run 3, mu 0.8, k 50 on cuda:1: CPUDispatcher(<function _get_center_double_context_windows at 0x7ebd664cbdc0>) returned a result with an error set
# [Task 55] Saved embeddings to /nobackup/gogandhi/alt_means_sans_k/data/experiment_n2v_metric_cosine_change_10000_50_3.0_minc50/Run_3/embeddings_LFR_n_10000_tau1_3.0_tau2_1.0_mu_0.8_k_50_mincomm_50.pkl
# [Task 64] Training model using cosine similarity for Run 4, mu 0.25, k 50 on cuda:0...[Task 62] Training model using cosine similarity for Run 4, mu 0.15, k 50 on cuda:0...[Task 59] Error training cosine model for Run 3, mu 1.0, k 50 on cuda:1: CPUDispatcher(<function _get_center_double_context_windows at 0x7ebd664cbdc0>) returned a result with an error set
#
#
# [Task 63] Training model using cosine similarity for Run 4, mu 0.2, k 50 on cuda:1...
# [Task 52] Error training cosine model for Run 3, mu 0.65, k 50 on cuda:0: CPUDispatcher(<function _get_center_double_context_windows at 0x7ebd664cbdc0>) returned a result with an error set
# [Task 59] Saved embeddings to /nobackup/gogandhi/alt_means_sans_k/data/experiment_n2v_metric_cosine_change_10000_50_3.0_minc50/Run_3/embeddings_LFR_n_10000_tau1_3.0_tau2_1.0_mu_1.0_k_50_mincomm_50.pkl
# [Task 65] Training model using cosine similarity for Run 4, mu 0.3, k 50 on cuda:1...[Task 66] Training model using cosine similarity for Run 4, mu 0.35, k 50 on cuda:0...
#
# [Task 52] Saved embeddings to /nobackup/gogandhi/alt_means_sans_k/data/experiment_n2v_metric_cosine_change_10000_50_3.0_minc50/Run_3/embeddings_LFR_n_10000_tau1_3.0_tau2_1.0_mu_0.65_k_50_mincomm_50.pkl
# [Task 67] Training model using cosine similarity for Run 4, mu 0.4, k 50 on cuda:1...[Task 69] Training model using cosine similarity for Run 4, mu 0.5, k 50 on cuda:1...[Task 68] Training model using cosine similarity for Run 4, mu 0.45, k 50 on cuda:0...
# [Task 70] Training model using cosine similarity for Run 4, mu 0.55, k 50 on cuda:0...
#
#
# [Task 73] Training model using cosine similarity for Run 4, mu 0.7, k 50 on cuda:1...[Task 72] Training model using cosine similarity for Run 4, mu 0.65, k 50 on cuda:0...[Task 71] Training model using cosine similarity for Run 4, mu 0.6, k 50 on cuda:1...
# [Task 74] Training model using cosine similarity for Run 4, mu 0.75, k 50 on cuda:0...
#
# [Task 75] Training model using cosine similarity for Run 4, mu 0.8, k 50 on cuda:1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 126
#     125 with tqdm(total=len(futures), desc=f"Processing k={k}", miniters=10) as pbar:
# --> 126     for future in as_completed(futures):
#     127         # Optionally get the result if you need to catch exceptions
#     128         future.result()
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     311 if timeout is None:
# --> 312     waiter.acquire()
#     313     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 129
#     128 future.result()
# --> 129 pbar.update(1)
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py:1140, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1139 try:
# -> 1140     self.close()
#    1141 except AttributeError:
#    1142     # maybe eager thread cleanup upon external error
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py:1275, in tqdm.close(self)
#    1274 pos = abs(self.pos)
# -> 1275 self._decr_instances(self)
#    1277 if self.last_print_t < self.start_t + self.delay:
#    1278     # haven't ever displayed; nothing to clear
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py:696, in tqdm._decr_instances(cls, instance)
#     688 """
#     689 Remove from list and reposition another unfixed bar
#     690 to fill the new gap.
#    (...)
#     694 (tqdm<=4.44.1 moved ALL subsequent unfixed bars up.)
#     695 """
# --> 696 with cls._lock:
#     697     try:
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py:111, in TqdmDefaultWriteLock.__enter__(self)
#     110 def __enter__(self):
# --> 111     self.acquire()
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/site-packages/tqdm/std.py:104, in TqdmDefaultWriteLock.acquire(self, *a, **k)
#     103 for lock in self.locks:
# --> 104     lock.acquire(*a, **k)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 129
#     126 for future in as_completed(futures):
#     127     # Optionally get the result if you need to catch exceptions
#     128     future.result()
# --> 129     pbar.update(1)
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/concurrent/futures/_base.py:637, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     636 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637     self.shutdown(wait=True)
#     638     return False
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/concurrent/futures/process.py:767, in ProcessPoolExecutor.shutdown(self, wait, cancel_futures)
#     764         self._executor_manager_thread_wakeup.wakeup()
#     766 if self._executor_manager_thread is not None and wait:
# --> 767     self._executor_manager_thread.join()
#     768 # To reduce the risk of opening too many files, remove references to
#     769 # objects that use file descriptors.
#     770 self._executor_manager_thread = None
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /nobackup/gogandhi/miniconda3/envs/gensim_mod_env/lib/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:
# [Task 76] Training model using cosine similarity for Run 4, mu 0.85, k 50 on cuda:0...[Task 77] Training model using cosine similarity for Run 4, mu 0.9, k 50 on cuda:1...
#
# [Task 78] Training model using cosine similarity for Run 4, mu 0.95, k 50 on cuda:0...
# [Task 81] Training model using cosine similarity for Run 5, mu 0.1, k 50 on cuda:1...[Task 80] Training model using cosine similarity for Run 5, mu 0.05, k 50 on cuda:0...
#
# [Task 79] Training model using cosine similarity for Run 4, mu 1.0, k 50 on cuda:1...[Task 82] Training model using cosine similarity for Run 5, mu 0.15, k 50 on cuda:0...
#
# [Task 84] Training model using cosine similarity for Run 5, mu 0.25, k 50 on cuda:0...[Task 83] Training model using cosine similarity for Run 5, mu 0.2, k 50 on cuda:1...[Task 85] Training model using cosine similarity for Run 5, mu 0.3, k 50 on cuda:1...
#
#
# [Task 86] Training model using cosine similarity for Run 5, mu 0.35, k 50 on cuda:0...
# [Task 87] Training model using cosine similarity for Run 5, mu 0.4, k 50 on cuda:1...
# [Task 88] Training model using cosine similarity for Run 5, mu 0.45, k 50 on cuda:0...
# [Task 89] Training model using cosine similarity for Run 5, mu 0.5, k 50 on cuda:1...
# [Task 90] Training model using cosine similarity for Run 5, mu 0.55, k 50 on cuda:0...
# [Task 91] Training model using cosine similarity for Run 5, mu 0.6, k 50 on cuda:1...
# [Task 92] Training model using cosine similarity for Run 5, mu 0.65, k 50 on cuda:0...
# [Task 93] Training model using cosine similarity for Run 5, mu 0.7, k 50 on cuda:1...
# [Task 94] Training model using cosine similarity for Run 5, mu 0.75, k 50 on cuda:0...
# [Task 95] Training model using cosine similarity for Run 5, mu 0.8, k 50 on cuda:1...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 31250/31250 [07:04<00:00, 73.68it/s, loss=1.12]
# [Task 80] Saved embeddings to /nobackup/gogandhi/alt_means_sans_k/data/experiment_n2v_metric_cosine_change_10000_50_3.0_minc50/Run_5/embeddings_LFR_n_10000_tau1_3.0_tau2_1.0_mu_0.05_k_50_mincomm_50.pkl
# [Task 96] Training model using cosine similarity for Run 5, mu 0.85, k 50 on cuda:0...
#  50%|████████████████████████████████████████████████▌                                                | 15654/31250 [03:28<04:11, 61.97it/s, loss=1.38]
